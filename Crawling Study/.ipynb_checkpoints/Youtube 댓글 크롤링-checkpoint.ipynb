# %% [markdown]
# ## Youtube 댓글 크롤링
#
#
# 댓글 추출한 동영상 링크 : https://www.youtube.com/watch?v=l9_i-LmBK_Y

# %% [markdown]
# ### 라이브러리
#
# pandas와 googleapiclient.discovery의 build사용 <br><br>
#
# 이때, **googleapiclient.discovery의 build**는 Google API를 호출하기 위한 객체를 지원하는 라이브러리

# %%
import pandas
from googleapiclient.discovery import build

# %% [markdown]
# #### utc 시간대를 추후에 편집하기 용이하게 하고자 만듬

# %%
def utc_change(df) :
    Year = df[0:4]
    Month = df[5:7]
    Day = df[8:10]
    hour = df[11:13]
    minute = df[14:16]
    second = df[17:19]
    
    return Year+'-'+Month+'-'+Day +' '+hour+':'+minute+':'+second

# %% [markdown]
# ### 토큰화
#
# 고유명사와 보통명사를 모두 살리는게 목적이다. + 불용어 없애기(불용어 사전 :https://www.ranks.nl/stopwords/korean 참고)

# %%
from nltk.tokenize import word_tokenize
from konlpy.tag import Okt
from konlpy.tag import Kkma, Hannanum, Komoran, Mecab, Twitter

# %%
def df_nouns(df) :
    okt = Okt()
    ndd = []
    car_names = ['eg80','eG80','Eg80','EG80','Gv80','GV80','gv80','gV80','Gv70','gv70','gV70','GV70']
    df['nouns_token'] = 0
    for car_name in car_names :
        for idx,value in enumerate(df.comment) :
            ndd.append(okt.nouns(value))
            if car_name in value :
                ndd[idx].append(car_name)
    ndd = ndd[0:len(df)]
    df['nouns_token'] = ndd
    
    return df

# %% [markdown]
# **YouTube Data API**는 다양한 정보를 지원한다(자세한 정보는 https://developers.google.com/youtube/v3/docs/commentThreads/list)
#
#
# 현재 예시는 4가지 정보만 활용
# ***
# **textDisplay :** 댓글의 내용<br><br>
# **authorDisplayName:** 댓글 작성자<br><br>
# **publishedAt:** 댓글 작성 시간<br><br>
# **likeCount:** 좋아요 수<br><br>
# ***
# ## Youtube 크롤링 코드

# %%
def give_me_comment(developerKey, videoid) :
    comments = list()
    api_obj = build('youtube', 'v3', developerKey= developerKey)
    response = api_obj.commentThreads().list(part='snippet,replies', videoId=videoid, maxResults=100).execute()

    while response:
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
            if item['snippet']['totalReplyCount'] > 0:
                for reply_item in item['replies']['comments']:
                    reply = reply_item['snippet']
                    comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
        if 'nextPageToken' in response:
            response = api_obj.commentThreads().list(part='snippet,replies', videoId=videoid, pageToken=response['nextPageToken'], maxResults=100).execute()
        else:
            break
    cols = ['comment', 'user name','Time','Thums Up']
    df = pandas.DataFrame(comments, columns = cols)
    df['Time'] = df['Time'].apply(lambda x : utc_change(x))
    
    # 토큰화 함수 추가
    df = df_nouns(df)
    return df

# %% [markdown]
# #### 최종 결과 : 28개의 댓글(대댓글 포함)

# %%
df1 = give_me_comment('google api', 'l9_i-LmBK_Y')
df1
# Out:
#                                               comment               user name  \
# 0   ✔ 선물용 끝판왕 차량용 방향제! 마일론 방향제!\r<br><a href="http...    남자들의 자동차 motorsjason
# 1               전기차 안나온다고 다들 이야기 했지만 나올줄 알았다 돈빨이 현다이라                    BB K
# 2             전기차를 살거면 아예 전기차 전용플랫폼으로 만든차를 사야하지않을까...                   G man
# 3   GV 70 은근 SUV답게 든든하네요.  Electrified GV70 아주 만족스...              Sour Lemon
# 4               제네시스 수소차 나오면 구입 할 생각있음 전기보다 장거리로 사용할거              Jinwoo Kim
# 5   반도체때메 차도 빨리 못만들면서 왜이렇게 신차들은 주구장창나오는걸까요 어차피또 7~...                     최정윤
# 6   기업이 그런것까지 고려해주면 좋은기업이겠지만 기업이 굳이 고려할필요는 없죠? 짐 현...                     뱅뱅뱅
# 7                    저도 저차 찍어서 올리기는 했는데 솔직히 찍을 때 쫄림ㅋㅋ     아이즈원,에스파는나야 둘이 될순없어
# 8                             깔끔하게 7500 만원 시작가 예상합니다.                    도르마무
# 9                                        아니야 아직은 전기차는                     이대길
# 10                 7천만원 중반대라니...... 전기차 언제쯤 살 수 있을지ㅠㅜ  교통사고에 관한 모든 이야기 [사고링크]
# 11  기대안한다 서비스 좆같이하는 기업이만든차 기대안함 테슬라잡겠다고 허세부려놓고 막상 ...               YouTube바임
# 12                  저 가격이면 외제차 사지...무슨 현기차를 저 가격에 사;;            tyutyu tutyu
# 13  중형 suv 프리미엄중에 제네시스에 꽂힌 소비자중 전기차를 사용하기 쉬운 환경에 살...                     뱅뱅뱅
# 14                             외제차는 수리비가 비싸요 뭘좀 모르시는듯                   푸른파수꾼
# 15              나중에 보조금 안나오면 7~8천차를 평범한직장인들은 사지도 못하겠네                   ᄉ단발머리
# 16                                     대량생산 하다보면 싸지겠지                     뭐하누
# 17                           전기차가 상용화되면서 가격이 낮아지지않을까요                 md park
# 18                                          가격이 참....        non-fiction 2020
# 19  <a href="https://www.youtube.com/watch?v=l9_i-...           GGOMA_꼬마 스튜디오
# 20  그릴을 eG80처럼 그냥 기존 그릴에 막아놓기만한 형상이 아니라... 재규어 I페이...                  Pigeon
# 21               GV70 수소전기차 생산해 주세요 프랑스 기름으로 가는차량 없어요                     이원준
# 22             제껀 클릭하면 안돼요♥\r<br>\r<br>말 좀 들어주셨으면 해요!      리탄TV 내 채널 들어오지마요 ꪜ
# 23                         영상 잘봤습니다.. 이것도 공공기관에서 쓰려나요               Daeun Kim
# 24  <a href="https://www.youtube.com/watch?v=l9_i-...                      햄찌
# 25                              중행 거리가.ㅡㅡgv80도나온다덴데..                     조성춘
# 26  가격이 eg80급일텐데... 메리트가 있으련지ㅜ 승차감 소재 고급감이야 아오5 ev...                     R P
# 27                          메리트는.... 얼마없는 전기SUV란것 정도?                     걍해봄
# 28                                        형 목소리 존나섹시해                 Park ST
# 12             [저, 가격, 이면, 외제차, 사지, 무슨, 기차, 저, 가격, 사]
# 13  [중형, 프리미엄, 제네시스, 소비자, 전기차, 사용, 환경, 살, 거, 돈, 대사...
# 14                                   [외제차, 수리, 비, 뭘좀]
# 15                                 [나중, 보조금, 직장인, 사지]
# 16                                             [대량생산]
# 17                                      [전기차, 상용, 가격]
# 18                                               [가격]
# 19                          [제, 사진, 남차, 유튭, 기대, Gv70]
# 20  [그릴, 처럼, 그냥, 기존, 그릴, 기만, 형상, 재규어, 페이스, 진짜, 그릴,...
# 21                   [수소, 전기차, 생산, 프랑스, 기름, 차량, GV70]
# 22                                  [제껀, 클릭, 말, 좀, 해]
# 23                                      [영상, 것, 공공기관]
# 24                                           [농담, 처음]
# 25                             [중행, 거리, 도나, 덴데, gv80]
# 26               [가격, 급, 메리트, 승, 차감, 소재, 급감, 뺨, eg80]
# 27                              [메리트, 얼마, 전기, 란것, 정도]
# 28                                       [형, 목소리, 존나]
# 29                              [으, 훨, 도, eg80, gv80]
# 30                     [제, 제일, 제네시스, 차종, 중, 하나, Gv70]
# 31     [제네시스, 전기차, 디자인, 전체, 살짝, 매력, 디자이너, 머리, 소리, 여기]
# 32                                  [시리즈, 그릴, 진짜, 별로]
# 33            [제네시스, 그릴, 디자인, 포인트, 전기차, 그릴, 디자이너, 힘좀]
# 34                                            [영상, 왜]

# %%
# 엑셀 저장 코드
# df1.to_excel('sample.xlsx', header=['comment', 'user name','Time','Thums Up'], index=None)

# %% [markdown]
# #### 혹시 몰라 댓글 100개 이상인 링크 댓글 개수도 뽑아봤다.(https://www.youtube.com/watch?v=7vmdwdRJkIA)

# %%
give_me_comment('google api','7vmdwdRJkIA')
# Out:
#                              comment  user name                 Time  \
# 0                         밴츠 영업사원 같다       가야왕자  2021-07-23 09:24:32
# 1    EQA 는 이미 정평(?) 나 있는데 이렇게 비교를;;;  Claus Max  2021-07-23 08:59:43
# 2                               유익했음       L Kh  2021-07-23 08:37:29
# 3          망가져간다는 차 엄마한테 드린다는 클라스 ㅋㅋ         십억  2021-07-23 08:31:16
# 4                       저런허접한 차를 6천씩       정에브리  2021-07-23 08:20:25
# ..                               ...        ...                  ...
# 475                     참지마시고 풀 시청!ㅋ       재뻘TV  2021-07-19 13:26:01
# 476                           안녕하세요~        김수민  2021-07-19 13:25:30
# 477                          안녕하세요^^       재뻘TV  2021-07-19 13:26:11
# 478                                1        우 진  2021-07-19 13:24:40
# 479                            1등 굿잡       재뻘TV  2021-07-19 13:26:18
#
#      Thums Up       nouns_token
# 0           0      [밴츠, 영업, 사원]
# 1           0       [정평, 나, 비교]
# 2           0                []
# 3           0  [간다, 차, 엄마, 클라스]
# 4           0        [저런, 접, 차]
# ..        ...               ...
# 475         0           [풀, 시청]
# 476         3                []
# 477         1                []
# 478         1                []
# 479         0              [굿잡]
#
# [480 rows x 5 columns]

# %% [markdown]
# #### 100개 이상도 잘나온다
