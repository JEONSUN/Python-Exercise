# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

# %%
# 빈창 만들기
options = webdriver.ChromeOptions()
options.add_argument('--start-maximized')

driver = webdriver.Chrome('chromedriver', options = options)

# %% [markdown]
# ### 수집할 사이트 정보 추출

# %%
# 사이트 링크 입력
url = "https://www.teamblind.com/kr/search/%EC%A0%84%EA%B8%B0%EC%B0%A8"
driver.get(url)

# 카테고리를 입력해야함
driver.find_element_by_xpath('//*[@id="m_channel"]/option[11]').click()

body = driver.find_element_by_tag_name('body') # body를 스크롤하기 위해 tagname이 body로 되어있는것을 추출합니다.
num_of_pagedowns = 300 

SCROLL_PAUSE_SEC = 1

# 스크롤 높이 가져옴
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 끝까지 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 1초 대기
    time.sleep(SCROLL_PAUSE_SEC)

    # 스크롤 다운 후 스크롤 높이 다시 가져옴
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print("페이지 읽기 종료")
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.close()
# Out:
# 페이지 읽기 종료

# %% [markdown]
# ### 원하는 정보 추출
#
# - 링크와 포스트 명

# %%
anchors = soup.find_all('a', {'class': '', 'href': True})
result = []
text_list = []
for i in anchors :
    result.append(i['href'])
    text_list.append(i.text)

# %%
link_text = pd.DataFrame({"link" : result, "text" : text_list})
link_text
# Out:
#                                                    link  \
# 0                                           /kr/company
# 1     /kr/post/%EC%A0%84%EA%B8%B0%EC%B0%A8-%EA%B3%A0...
# 2                /kr/topics/%EC%9E%90%EB%8F%99%EC%B0%A8
# 3     /kr/post/%EC%A0%84%EA%B8%B0%EC%B0%A8-%EA%B3%A0...
# 4     /kr/post/%EC%A0%84%EA%B8%B0%EC%B0%A8-%EA%B3%A0...
# ...                                                 ...
# 3291                                      /kr/introduce
# 3292              https://kr.teamblind.com/setting/term
# 3293                                        /kr/sitemap
# 3294           https://kr.teamblind.com/setting/privacy
# 3295                                     /kr/contact-us
#
#                                                    text
# 0                                                 기업 리뷰
# 1
# 2                                                   자동차
# 3                                                전기차 고민
# 4     아는 지인분이 테슬라 Y로 바꾸셨는데  와 생각보다 차가 크더라고  차 바꿀때가 돼...
# ...                                                 ...
# 3291                                             서비스 소개
# 3292                                               이용약관
# 3293                                               디렉토리
# 3294                                          개인정보 처리방침
# 3295                                    Blind Hub 기업서비스
#
# [3296 rows x 2 columns]

# %%
url = 'https://www.teamblind.com'
url_list = []
text_list = []
for i in range(1,len(link_text)) :
    if link_text['text'][i] == "자동차" :
        url_list.append(url + str(link_text['link'][i+1]))
        text_list.append(str(link_text['text'][i+1]))
        if link_text['link'][i].find('post') == 0 :
            pass

# %%
url_df = pd.DataFrame({"url": url_list,"text" : text_list})
#url_df.to_excel("블라인드(전기자동차 - 자동차)링크.xlsx",index = None)

# %%
url_df
# Out:
#                                                    url  \
# 0    https://www.teamblind.com/kr/post/%EC%A0%84%EA...
# 1    https://www.teamblind.com/kr/post/%EC%A0%84%EA...
# 2    https://www.teamblind.com/kr/post/%EC%A0%84%EA...
# 3    https://www.teamblind.com/kr/post/%EC%A0%84%EA...
# 4    https://www.teamblind.com/kr/post/%EC%A0%84%EA...
# ..                                                 ...
# 642  https://www.teamblind.com/kr/post/%ED%98%95%EB...
# 643  https://www.teamblind.com/kr/post/%ED%85%8C%EC...
# 644  https://www.teamblind.com/kr/post/GV70-35%ED%8...
# 645  https://www.teamblind.com/kr/post/%EC%A0%9C%EA...
# 646  https://www.teamblind.com/kr/post/%ED%98%84%EB...
#
#                                                   text
# 0                                               전기차 고민
# 1                                           전기차 타는 형들
# 2                                             전기차 구매투표
# 3                                               전기차!!!
# 4                                              전기차 말이야
# ..                                                 ...
# 642                               형들의 조언을 받아 차를 고민해봤는데
# 643                              테슬라 모델 X 2년타본 느낌? 후기?
# 644                        GV70 3.5터보 가솔린 6천킬로 후기(초스압)
# 645                                  제가 꼽는 최고의 브랜드 세번째
# 646  현대차는 잘못하면 안드로이드 못쓰는 화웨이, 잘되어도 폭스콘이 될지도 모른다. - ...
#
# [647 rows x 2 columns]

# %% [markdown]
# ### 해당 링크를 통해 포스트명, 본문, 댓글 추출

# %%
# 제목, 내용, 댓글 추출
title_list = []
main_list = []
comment_list = []
options = webdriver.ChromeOptions()
options.add_argument('--start-maximized')
driver = webdriver.Chrome('chromedriver', options = options)
def blind_scraping(url) :
    url = url
    driver.get(url)
    time.sleep(0.5)
    titles = driver.find_element_by_xpath('//*[@id="wrap"]/section/div/div[1]/div[1]/h2').text
    main = driver.find_element_by_xpath('//*[@id="contentArea"]').text
    comment = driver.find_element_by_xpath('//*[@id="wrap"]/section/div/div[1]/div[4]').text
    title_list.append(titles)
    main_list.append(main)
    comment_list.append(comment)
    df = pd.DataFrame({'title' : title_list,'main' : main_list,'comment' : comment_list})
    print("정리 끝")
    return df

# %%
for i in range(0,len(url_df)+1) :
    url = url_df['url'][i]
    please1 = blind_scraping(url)
# Out:
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# 정리 끝
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 647 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0f3919dada27> in <module>
#       1 for i in range(0,len(url_df)+1) :
# ----> 2     url = url_df['url'][i]
#       3     please1 = blind_scraping(url)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 647

# %%
please1
# Out:
#                                                  title  \
# 0                                               전기차 고민
# 1                                            전기차 타는 형들
# 2                                               전기차 구매
# 3                                               전기차!!!
# 4                                              전기차 말이야
# ..                                                 ...
# 642                               형들의 조언을 받아 차를 고민해봤는데
# 643                              테슬라 모델 X 2년타본 느낌? 후기?
# 644                        GV70 3.5터보 가솔린 6천킬로 후기(초스압)
# 645                                  제가 꼽는 최고의 브랜드 세번째
# 646  현대차는 잘못하면 안드로이드 못쓰는 화웨이, 잘되어도 폭스콘이 될지도 모른다. - ...
#
#                                                   main  \
# 0    아는 지인분이 테슬라 Y로 바꾸셨는데\n와 생각보다 차가 크더라고\n\n차 바꿀때가...
# 1        충전료 많이 올랐어요??\n휘발유랑 별 차이 없어요??\n전기차 취소 해야함? 🥲
# 2    차량 구매욕구가 불타오르는데 요즘 핫한 전기차 중 무엇을 골라야할지\n\n차량 자체...
# 3                                      테슬라 사는 이유가 뭔가유?
# 4    전기차는 정속주행을 하는것보다\n가감속으로 계속 속도에 변화를 주면서 회생제동을 이...
# ..                                                 ...
# 642  이래저래 가용 현금(일시불) 4천 정도를 보고있어.\n\n주말 450km\n평일 4...
# 643  안녕 친구들.\n나는 미국살고..2년전에 모델 X 흰색+흰색 75D 5시트로 샀었어...
# 644  지난 3월 8일에 GV70을 출고한 이후 지금까지 6천킬로를 탔어.\n옵션은 3.5...
# 645  벌써 세번째 글이 되었네요\n\n많은 분들이 리플로 좋은 말씀과 제가 간과하거나 잘...
# 646  테슬라의 진정한 강점은 전기차 제조가 아닌 자율주행체계를 완성해가고 있는 것에 있다...
#
#                                                comment
# 0    댓글 6\n댓글을 남겨주세요.\n도레이첨단소재 · c*****\n오파 빼.\n단종됐...
# 1    댓글 39\n댓글을 남겨주세요.\n현대엘리베이터 · W***\n그래도 멀었다 전기차...
# 2    댓글 50\n댓글을 남겨주세요.\n댓글 13개 더보기\n삼성SDI · l******...
# 3    댓글 10\n댓글을 남겨주세요.\nLG전자 · i********\n간지\n작성일\n...
# 4    댓글 7\n댓글을 남겨주세요.\n한국화이자 · !*******\n맞음 근데 그정도 ...
# ..                                                 ...
# 642  댓글 19\n댓글을 남겨주세요.\n롯데오토케어 · 정*********\n코나EV\n...
# 643  댓글 13\n댓글을 남겨주세요.\nLG전자 · i*********\n모델명이 75D...
# 644  댓글 23\n댓글을 남겨주세요.\n댓글 5개 더보기\nH&M · l*********...
# 645  댓글 81\n댓글을 남겨주세요.\n댓글 50개 더보기\nLG화학 · m*******...
# 646  댓글 37\n댓글을 남겨주세요.\n댓글 20개 더보기\n한국GM · a**\n안개만...
#
# [647 rows x 3 columns]

# %%
please1['url'] = url_df['url']
please1 = please1[['title','url','main','comment']]

# %%
please1.to_excel('블라인드(검색 전기차, 자동차 파트).xlsx',index = None)
