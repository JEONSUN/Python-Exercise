# %%
import numpy as np
np.random.seed(1234)

x = np.random.normal(170., 5.0, size=1000)    

maxValue = x[0]
for i in range(1, len(x)):
    if maxValue < x[i]:
        maxValue = x[i]


print('%.2f' % maxValue)
pass
# Out:
# 183.82

# %%
import numpy as np
np.random.uniform(size=10000)
count=0
for i in range(n):
  x=np.random.random()
  y=np.random.random()
  if(x*x+y*y<1):
    count=count+1
a=4*count/n
def piEstimate (n):
    pass
print(a)
# Out:
# 3.208

# %%
import pandas as pd
data = pd.read_csv('C:/Users/82104/Desktop/빅데/MLBattend.csv',sep=',',na_values=".")
print(data)
# Out:
#      Unnamed: 0 franchise league division  year  attendance  runs.scored  \
# 0             1       BAL     AL     EAST    69     1062069          779
# 1             2       BOS     AL     EAST    69     1833246          743
# 2             3       CLE     AL     EAST    69      619970          573
# 3             4       DET     AL     EAST    69     1577481          701
# 4             5       NYA     AL     EAST    69     1067996          562
# 5             6       WAS     AL     EAST    69      918106          694
# 6             7       CAL     AL     WEST    69      758388          528
# 7             8      CHIA     AL     WEST    69      589546          625
# 8             9        KC     AL     WEST    69      902414          586
# 9            10       MIN     AL     WEST    69     1349328          790
# 10           11       OAK     AL     WEST    69      778232          740
# 11           12       SEA     AL     WEST    69      677944          639
# ...

# %%
data2 = data[ ["league","attendance","runs.scored","runs.allowed"] ]

# %%
data2.groupby(['league'], as_index=False).mean()
# Out:
#   league    attendance  runs.scored  runs.allowed
# 0     AL  1.716321e+06   713.293981    713.490741
# 1     NL  1.843617e+06   675.411330    675.100985

# %%
data2.groupby(['league'], as_index=False).corr()
# Out:
#                 attendance  runs.scored  runs.allowed
# 0 attendance      1.000000     0.554555      0.168597
#   runs.scored     0.554555     1.000000      0.561632
#   runs.allowed    0.168597     0.561632      1.000000
# 1 attendance      1.000000     0.482578      0.051004
#   runs.scored     0.482578     1.000000      0.540466
#   runs.allowed    0.051004     0.540466      1.000000
