# %% [markdown]
# ## 성능데이터모델링의 개요
#
#
# ### 성능데이터모델링의 정의
#
# - 데이터모델링을 할 때 어떤 작업유형에 따라 성능향상을 도모해야하는지, 목표를 분명하게해야 정확한 성능향상 모델링을 할 수 있다.
#
# - 목표를 분명하게 해야 정확한 성능향상 모델링을 할 수 있다.
#
# ### 성능 데이터모델링 수행 시점
#
# - 분석/설계단계에서 데이터베이스 처리 성능을 향상시킬 수 있는 방법을 고려해야한다.
#
# ### 성능 데이터모델링 고려사항
#
# - 정규화와 반정규화
#
#
# ## 정규화와 반정규화
#
# - 일반적으로 정규화가 잘되어있으면 입력/수정/삭제의 성능이 향상되고 반정규화를 많이 하면 조회의 성능이 향상된다.
# ***
# ## 정규화와 성능
#
# ### 1. 정규화를 통한 성능향상전략
#
# - **데이터에 대한 중복성을 제거해준다.**
#
# - 그만큼 조인이 많이 발생하기때문에 그에따른 성능저하가 발생할 수 있다.
#
#
#
# 반정규화를 무분별하게 진행할 경우 데이터 무결성을 깨뜨린다.
#
# ### 반정규화는 언제 진행하는가?
#
# > - 자주 사용되는 테이블에 접근하는 프로세스의 수가 많고 항상 일정한 범위만을 조회하는 경우
# >
# > - 테이블에 대량의 데이터가 있고 대량의 데이터 범위를 자주 처리하는 경우, 처리 범위를 줄이지 않으면 성능을 보장 할 수 없는 경우
# >
# > - 테이블에 지나친 조인이 걸려있을 경우

# %% [markdown]
# ***
# ## 1차 정규화
#
# - 항상 더이상 분해가 불가능한 원자값을 갖는다. ROW별로 1개의 컬럼값을 가진다.
#
#
#
# ***
# ## 2차 정규화
#
# - 기본 키에 의존하는 것이 아닌 일반 열에도 속하는 경우
